# %%
import pandas as pd

gen_data = pd.read_excel('annual_generation_state.xls', names=[''])

# %%
gen_data
# Out:
#       State Historical Tables for 2018\nReleased: September 2019\nRevised: November 2019\nNext Update: November 2020  \
# 0                                                   YEAR
# 1                                                   1990
# 2                                                   1990
# 3                                                   1990
# 4                                                   1990
# ...                                                  ...
# 51629                                               2018
# 51630                                               2018
# 51631                                               2018
# 51632                                               2018
# 51633                                               2018
#
#       Unnamed: 1                               Unnamed: 2  \
# 0          STATE                         TYPE OF PRODUCER
# 1             AK            Total Electric Power Industry
# ...
